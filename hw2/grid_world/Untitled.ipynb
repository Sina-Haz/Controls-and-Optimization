# %%
from grid_world import *
from value_iteration import *

# %%
world = GridWorld()

# %%
# %matplotlib inline
threshold = 0.0001
gamma = 0.9
print(f'Computing Value Iteration with discount = {gamma}')
V_opt1, u_opt1 = value_iteration(world, threshold, gamma, True)
# Out:
# Computing Value Iteration with discount = 0.9
# Number of iterations to convergence: 20

# %%
# try different gammas
value_iteration(world, threshold, gamma=1);
# Out:
# Number of iterations to convergence: 21

# %%
value_iteration(world, threshold, gamma=0.7);
# Out:
# Number of iterations to convergence: 17

# %%
value_iteration(world, threshold, gamma=0.5);
# Out:
# Number of iterations to convergence: 14

# %%
value_iteration(world, threshold, gamma=0.1);
# Out:
# Number of iterations to convergence: 6

# %%
gamma=0.000001
print(f'Computing Value Iteration with discount = {gamma}')
value_iteration(world, threshold, gamma=0.000001);
# Out:
# Computing Value Iteration with discount = 1e-06
# Number of iterations to convergence: 2
